# %% [markdown]
# # Generative Adversarial Networks (GANs)
#
# So far in CS231N, all the applications of neural networks that we have explored have been **discriminative models** that take an input and are trained to produce a labeled output. This has ranged from straightforward classification of image categories to sentence generation (which was still phrased as a classification problem, our labels were in vocabulary space and we’d learned a recurrence to capture multi-word labels). In this notebook, we will expand our repetoire, and build **generative models** using neural networks. Specifically, we will learn how to build models which generate novel images that resemble a set of training images.
#
# ### What is a GAN?
#
# In 2014, [Goodfellow et al.](https://arxiv.org/abs/1406.2661) presented a method for training generative models called Generative Adversarial Networks (GANs for short). In a GAN, we build two different neural networks. Our first network is a traditional classification network, called the **discriminator**. We will train the discriminator to take images, and classify them as being real (belonging to the training set) or fake (not present in the training set). Our other network, called the **generator**, will take random noise as input and transform it using a neural network to produce images. The goal of the generator is to fool the discriminator into thinking the images it produced are real.
#
# We can think of this back and forth process of the generator ($G$) trying to fool the discriminator ($D$), and the discriminator trying to correctly classify real vs. fake as a minimax game:
# $$\underset{G}{\text{minimize}}\; \underset{D}{\text{maximize}}\; \mathbb{E}_{x \sim p_\text{data}}\left[\log D(x)\right] + \mathbb{E}_{z \sim p(z)}\left[\log \left(1-D(G(z))\right)\right]$$
# where $x \sim p_\text{data}$ are samples from the input data, $z \sim p(z)$ are the random noise samples, $G(z)$ are the generated images using the neural network generator $G$, and $D$ is the output of the discriminator, specifying the probability of an input being real. In [Goodfellow et al.](https://arxiv.org/abs/1406.2661), they analyze this minimax game and show how it relates to minimizing the Jensen-Shannon divergence between the training data distribution and the generated samples from $G$.
#
# To optimize this minimax game, we will aternate between taking gradient *descent* steps on the objective for $G$, and gradient *ascent* steps on the objective for $D$:
# 1. update the **generator** ($G$) to minimize the probability of the __discriminator making the correct choice__.
# 2. update the **discriminator** ($D$) to maximize the probability of the __discriminator making the correct choice__.
#
# While these updates are useful for analysis, they do not perform well in practice. Instead, we will use a different objective when we update the generator: maximize the probability of the **discriminator making the incorrect choice**. This small change helps to allevaiate problems with the generator gradient vanishing when the discriminator is confident. This is the standard update used in most GAN papers, and was used in the original paper from [Goodfellow et al.](https://arxiv.org/abs/1406.2661).
#
# In this assignment, we will alternate the following updates:
# 1. Update the generator ($G$) to maximize the probability of the discriminator making the incorrect choice on generated data:
# $$\underset{G}{\text{maximize}}\;  \mathbb{E}_{z \sim p(z)}\left[\log D(G(z))\right]$$
# 2. Update the discriminator ($D$), to maximize the probability of the discriminator making the correct choice on real and generated data:
# $$\underset{D}{\text{maximize}}\; \mathbb{E}_{x \sim p_\text{data}}\left[\log D(x)\right] + \mathbb{E}_{z \sim p(z)}\left[\log \left(1-D(G(z))\right)\right]$$
#
# ### What else is there?
# Since 2014, GANs have exploded into a huge research area, with massive [workshops](https://sites.google.com/site/nips2016adversarial/), and [hundreds of new papers](https://github.com/hindupuravinash/the-gan-zoo). Compared to other approaches for generative models, they often produce the highest quality samples but are some of the most difficult and finicky models to train (see [this github repo](https://github.com/soumith/ganhacks) that contains a set of 17 hacks that are useful for getting models working). Improving the stabiilty and robustness of GAN training is an open research question, with new papers coming out every day! For a more recent tutorial on GANs, see [here](https://arxiv.org/abs/1701.00160). There is also some even more recent exciting work that changes the objective function to Wasserstein distance and yields much more stable results across model architectures: [WGAN](https://arxiv.org/abs/1701.07875), [WGAN-GP](https://arxiv.org/abs/1704.00028).
#
#
# GANs are not the only way to train a generative model! For other approaches to generative modeling check out the [deep generative model chapter](http://www.deeplearningbook.org/contents/generative_models.html) of the Deep Learning [book](http://www.deeplearningbook.org). Another popular way of training neural networks as generative models is Variational Autoencoders (co-discovered [here](https://arxiv.org/abs/1312.6114) and [here](https://arxiv.org/abs/1401.4082)). Variational autoencoders combine neural networks with variational inference to train deep generative models. These models tend to be far more stable and easier to train but currently don't produce samples that are as pretty as GANs.
#
# Example pictures of what you should expect (yours might look slightly different):
#
# ![caption](gan_outputs_tf.png)

# %% [markdown]
# ## Setup

# %%
from __future__ import print_function, division
import tensorflow as tf
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# A bunch of utility functions

def show_images(images):
    images = np.reshape(images, [images.shape[0], -1])  # images reshape to (batch_size, D)
    sqrtn = int(np.ceil(np.sqrt(images.shape[0])))
    sqrtimg = int(np.ceil(np.sqrt(images.shape[1])))

    fig = plt.figure(figsize=(sqrtn, sqrtn))
    gs = gridspec.GridSpec(sqrtn, sqrtn)
    gs.update(wspace=0.05, hspace=0.05)

    for i, img in enumerate(images):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        print(tf.shape(img))
        print(sqrtimg)
        plt.imshow(img.reshape([sqrtimg,sqrtimg]))
    return

def preprocess_img(x):
    return 2 * x - 1.0

def deprocess_img(x):
    return (x + 1.0) / 2.0

def rel_error(x,y):
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def count_params():
    """Count the number of parameters in the current TensorFlow graph """
    param_count = np.sum([np.prod(x.get_shape().as_list()) for x in tf.global_variables()])
    return param_count


def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    session = tf.Session(config=config)
    return session

answers = np.load('gan-checks-tf.npz')

# %% [markdown]
# ## Dataset
#  GANs are notoriously finicky with hyperparameters, and also require many training epochs. In order to make this assignment approachable without a GPU, we will be working on the MNIST dataset, which is 60,000 training and 10,000 test images. Each picture contains a centered image of white digit on black background (0 through 9). This was one of the first datasets used to train convolutional neural networks and it is fairly easy -- a standard CNN model can easily exceed 99% accuracy.
#
# To simplify our code here, we will use the TensorFlow MNIST wrapper, which downloads and loads the MNIST dataset. See the [documentation](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/contrib/learn/python/learn/datasets/mnist.py) for more information about the interface. The default parameters will take 5,000 of the training examples and place them into a validation dataset. The data will be saved into a folder called `MNIST_data`.
#
# **Heads-up**: The TensorFlow MNIST wrapper returns images as vectors. That is, they're size (batch, 784). If you want to treat them as images, we have to resize them to (batch,28,28) or (batch,28,28,1). They are also type np.float32 and bounded [0,1].

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('./cs231n/datasets/MNIST_data', one_hot=False)

# show a batch
show_images(mnist.train.next_batch(16)[0])
# Out:
# Extracting ./cs231n/datasets/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./cs231n/datasets/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./cs231n/datasets/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./cs231n/datasets/MNIST_data/t10k-labels-idx1-ubyte.gz
# Tensor("Shape_6:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_7:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_8:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_9:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_10:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_11:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_12:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_13:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_14:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_15:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_16:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_17:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_18:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_19:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_20:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_21:0", shape=(1,), dtype=int32)
# 28

# %% [markdown]
# ## LeakyReLU
# In the cell below, you should implement a LeakyReLU. See the [class notes](http://cs231n.github.io/neural-networks-1/) (where alpha is small number) or equation (3) in [this paper](http://ai.stanford.edu/~amaas/papers/relu_hybrid_icml2013_final.pdf). LeakyReLUs keep ReLU units from dying and are often used in GAN methods (as are maxout units, however those increase model size and therefore are not used in this notebook).
#
# HINT: You should be able to use `tf.maximum`

# %%
def leaky_relu(x, alpha=0.01):
    """Compute the leaky ReLU activation function.
    
    Inputs:
    - x: TensorFlow Tensor with arbitrary shape
    - alpha: leak parameter for leaky ReLU
    
    Returns:
    TensorFlow Tensor with the same shape as x
    """
    # TODO: implement leaky ReLU
    pass
    return tf.maximum(x,alpha * x)

# %% [markdown]
# Test your leaky ReLU implementation. You should get errors < 1e-10

# %%
def test_leaky_relu(x, y_true):
    tf.reset_default_graph()
    with get_session() as sess:
        y_tf = leaky_relu(tf.constant(x))
        y = sess.run(y_tf)
        print('Maximum error: %g'%rel_error(y_true, y))

test_leaky_relu(answers['lrelu_x'], answers['lrelu_y'])
# Out:
# Maximum error: 0

# %% [markdown]
# ## Random Noise
# Generate a TensorFlow `Tensor` containing uniform noise from -1 to 1 with shape `[batch_size, dim]`.

# %%
def sample_noise(batch_size, dim):
    """Generate random uniform noise from -1 to 1.
    
    Inputs:
    - batch_size: integer giving the batch size of noise to generate
    - dim: integer giving the dimension of the the noise to generate
    
    Returns:
    TensorFlow Tensor containing uniform noise in [-1, 1] with shape [batch_size, dim]
    """
    # TODO: sample and return noise
    pass
    x = tf.random_uniform(shape=[batch_size,dim],minval = -1,dtype=tf.float32,seed=None,name=None)
    return x

# %% [markdown]
# Make sure noise is the correct shape and type:

# %%
def test_sample_noise():
    batch_size = 3
    dim = 4
    tf.reset_default_graph()
    with get_session() as sess:
        z = sample_noise(batch_size, dim)
        # Check z has the correct shape
        assert z.get_shape().as_list() == [batch_size, dim]
        # Make sure z is a Tensor and not a numpy array
        assert isinstance(z, tf.Tensor)
        # Check that we get different noise for different evaluations
        z1 = sess.run(z)
        z2 = sess.run(z)
        assert not np.array_equal(z1, z2)
        # Check that we get the correct range
        assert np.all(z1 >= -1.0) and np.all(z1 <= 1.0)
        print("All tests passed!")
    
test_sample_noise()
# Out:
# All tests passed!

# %% [markdown]
# ## Discriminator
# Our first step is to build a discriminator. You should use the layers in `tf.layers` to build the model.
# All fully connected layers should include bias terms.
#
# Architecture:
#  * Fully connected layer from size 784 to 256
#  * LeakyReLU with alpha 0.01
#  * Fully connected layer from 256 to 256
#  * LeakyReLU with alpha 0.01
#  * Fully connected layer from 256 to 1
#
# The output of the discriminator should have shape `[batch_size, 1]`, and contain real numbers corresponding to the scores that each of the `batch_size` inputs is a real image.

# %%
def discriminator(x):
    """Compute discriminator score for a batch of input images.
    
    Inputs:
    - x: TensorFlow Tensor of flattened input images, shape [batch_size, 784]
    
    Returns:
    TensorFlow Tensor with shape [batch_size, 1], containing the score 
    for an image being real for each input image.
    """
    with tf.variable_scope("discriminator"):
        # TODO: implement architecture
        pass
        h1 = tf.layers.dense(inputs = x,units = 256, use_bias = True,activation = None)
        h1 = leaky_relu(h1,alpha = 0.01)
        h2 = tf.layers.dense(inputs = h1,units = 256,use_bias = True, activation = None)
        h2 = leaky_relu(h2,alpha = 0.01)
        logits = tf.layers.dense(inputs = h2,units = 1)
        
        return logits

# %% [markdown]
# Test to make sure the number of parameters in the discriminator is correct:

# %%
def test_discriminator(true_count=267009):
    tf.reset_default_graph()
    with get_session() as sess:
        y = discriminator(tf.ones((2, 784)))
        cur_count = count_params()
        if cur_count != true_count:
            print('Incorrect number of parameters in discriminator. {0} instead of {1}. Check your achitecture.'.format(cur_count,true_count))
        else:
            print('Correct number of parameters in discriminator.')
        
test_discriminator()
# Out:
# Correct number of parameters in discriminator.

# %% [markdown]
# ## Generator
# Now to build a generator. You should use the layers in `tf.layers` to construct the model. All fully connected layers should include bias terms.
#
# Architecture:
#  * Fully connected layer from tf.shape(z)[1] (the number of noise dimensions) to 1024
#  * ReLU
#  * Fully connected layer from 1024 to 1024
#  * ReLU
#  * Fully connected layer from 1024 to 784
#  * TanH (To restrict the output to be [-1,1])

# %%
def generator(z):
    """Generate images from a random noise vector.
    
    Inputs:
    - z: TensorFlow Tensor of random noise with shape [batch_size, noise_dim]
    
    Returns:
    TensorFlow Tensor of generated images, with shape [batch_size, 784].
    """
    with tf.variable_scope("generator"):
        # TODO: impbvvlement architecture
        pass
        f1 = tf.layers.dense(inputs = z,units = 1024, use_bias = True,activation = tf.nn.relu)
        f2 = tf.layers.dense(inputs = f1,units = 1024,use_bias = True, activation = tf.nn.relu)
        f3 = tf.layers.dense(inputs = f2,units = 784,use_bias = True, activation = tf.nn.tanh)
        return f3

# %% [markdown]
# Test to make sure the number of parameters in the generator is correct:

# %%
def test_generator(true_count=1858320):
    tf.reset_default_graph()
    with get_session() as sess:
        y = generator(tf.ones((1, 4)))
        cur_count = count_params()
        if cur_count != true_count:
            print('Incorrect number of parameters in generator. {0} instead of {1}. Check your achitecture.'.format(cur_count,true_count))
        else:
            print('Correct number of parameters in generator.')
        
test_generator()
# Out:
# Correct number of parameters in generator.

# %% [markdown]
# # GAN Loss
#
# Compute the generator and discriminator loss. The generator loss is:
# $$\ell_G  =  -\mathbb{E}_{z \sim p(z)}\left[\log D(G(z))\right]$$
# and the discriminator loss is:
# $$ \ell_D = -\mathbb{E}_{x \sim p_\text{data}}\left[\log D(x)\right] - \mathbb{E}_{z \sim p(z)}\left[\log \left(1-D(G(z))\right)\right]$$
# Note that these are negated from the equations presented earlier as we will be *minimizing* these losses.
#
# **HINTS**: Use [tf.ones_like](https://www.tensorflow.org/api_docs/python/tf/ones_like) and [tf.zeros_like](https://www.tensorflow.org/api_docs/python/tf/zeros_like) to generate labels for your discriminator. Use [sigmoid_cross_entropy loss](https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits) to help compute your loss function. Instead of computing the expectation, we will be averaging over elements of the minibatch, so make sure to combine the loss by averaging instead of summing.

# %%
def gan_loss(logits_real, logits_fake):
    """Compute the GAN loss.
    
    Inputs:
    - logits_real: Tensor, shape [batch_size, 1], output of discriminator
        Log probability that the image is real for each real image
    - logits_fake: Tensor, shape[batch_size, 1], output of discriminator
        Log probability that the image is real for each fake image
    
    Returns:
    - D_loss: discriminator loss scalar
    - G_loss: generator loss scalar
    """
    # TODO: compute D_loss and G_loss
    D_loss = None
    G_loss = None
    pass
    img1 = tf.ones_like(logits_real)
    shape1 = tf.shape(img1)
    img2 = tf.zeros_like(logits_fake)
    shape2 = tf.shape(img2)
    print(img1,img2)
    
    loss1 = tf.nn.sigmoid_cross_entropy_with_logits(labels = img1,logits = logits_real)
    loss2 = tf.nn.sigmoid_cross_entropy_with_logits(labels = img2,logits = logits_fake)
    loss3 = tf.nn.sigmoid_cross_entropy_with_logits(labels = img1,logits = logits_fake)
    D_loss =  tf.reduce_mean(loss1) + tf.reduce_mean(loss2)
    G_loss =  tf.reduce_mean(loss3)
    return D_loss, G_loss

# %% [markdown]
# Test your GAN loss. Make sure both the generator and discriminator loss are correct. You should see errors less than 1e-5.

# %%
def test_gan_loss(logits_real, logits_fake, d_loss_true, g_loss_true):
    tf.reset_default_graph()
    with get_session() as sess:
        d_loss, g_loss = sess.run(gan_loss(tf.constant(logits_real), tf.constant(logits_fake)))
    print("Maximum error in d_loss: %g"%rel_error(d_loss_true, d_loss))
    print("Maximum error in g_loss: %g"%rel_error(g_loss_true, g_loss))

test_gan_loss(answers['logits_real'], answers['logits_fake'],
              answers['d_loss_true'], answers['g_loss_true'])
# Out:
# Tensor("ones_like:0", shape=(10, 1), dtype=float64) Tensor("zeros_like:0", shape=(10, 1), dtype=float64)
# Maximum error in d_loss: 0
# Maximum error in g_loss: 7.19722e-17

# %% [markdown]
# # Optimizing our loss
# Make an `AdamOptimizer` with a 1e-3 learning rate, beta1=0.5 to mininize G_loss and D_loss separately. The trick of decreasing beta was shown to be effective in helping GANs converge in the [Improved Techniques for Training GANs](https://arxiv.org/abs/1606.03498) paper. In fact, with our current hyperparameters, if you set beta1 to the Tensorflow default of 0.9, there's a good chance your discriminator loss will go to zero and the generator will fail to learn entirely. In fact, this is a common failure mode in GANs; if your D(x) learns to be too fast (e.g. loss goes near zero), your G(z) is never able to learn. Often D(x) is trained with SGD with Momentum or RMSProp instead of Adam, but here we'll use Adam for both D(x) and G(z).

# %%
# TODO: create an AdamOptimizer for D_solver and G_solver
def get_solvers(learning_rate=1e-3, beta1=0.5):
    """Create solvers for GAN training.
    
    Inputs:
    - learning_rate: learning rate to use for both solvers
    - beta1: beta1 parameter for both solvers (first moment decay)
    
    Returns:
    - D_solver: instance of tf.train.AdamOptimizer with correct learning_rate and beta1
    - G_solver: instance of tf.train.AdamOptimizer with correct learning_rate and beta1
    """
    D_solver = None
    G_solver = None
    pass
    D_solver = tf.train.AdamOptimizer(learning_rate = learning_rate,beta1 = beta1)
    G_solver = tf.train.AdamOptimizer(learning_rate = learning_rate,beta1 = beta1)

    return D_solver, G_solver

# %% [markdown]
# ## Putting it all together
# Now just a bit of Lego Construction.. Read this section over carefully to understand how we'll be composing the generator and discriminator

# %%
tf.reset_default_graph()

# number of images for each batch
batch_size = 128
# our noise dimension
noise_dim = 96

# placeholder for images from the training dataset
x = tf.placeholder(tf.float32, [None, 784])
# random noise fed into our generator
z = sample_noise(batch_size, noise_dim)
# generated images
G_sample = generator(z)

with tf.variable_scope("") as scope:
    #scale images to be -1 to 1
    logits_real = discriminator(preprocess_img(x))
    # Re-use discriminator weights on new inputs
    scope.reuse_variables()
    logits_fake = discriminator(G_sample)

# Get the list of variables for the discriminator and generator
D_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'discriminator')
G_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'generator') 

# get our solver
D_solver, G_solver = get_solvers()

# get our loss
D_loss, G_loss = gan_loss(logits_real, logits_fake)

# setup training steps
D_train_step = D_solver.minimize(D_loss, var_list=D_vars)
G_train_step = G_solver.minimize(G_loss, var_list=G_vars)
D_extra_step = tf.get_collection(tf.GraphKeys.UPDATE_OPS, 'discriminator')
G_extra_step = tf.get_collection(tf.GraphKeys.UPDATE_OPS, 'generator')
# Out:
# Tensor("ones_like:0", shape=(?, 1), dtype=float32) Tensor("zeros_like:0", shape=(128, 1), dtype=float32)

# %% [markdown]
# # Training a GAN!
# Well that wasn't so hard, was it? In the iterations in the low 100s you should see black backgrounds, fuzzy shapes as you approach iteration 1000, and decent shapes, about half of which will be sharp and clearly recognizable as we pass 3000. In our case, we'll simply train D(x) and G(z) with one batch each every iteration. However, papers often experiment with different schedules of training D(x) and G(z), sometimes doing one for more steps than the other, or even training each one until the loss gets "good enough" and then switching to training the other.

# %%
# a giant helper function
def run_a_gan(sess, G_train_step, G_loss, D_train_step, D_loss, G_extra_step, D_extra_step,\
              show_every=250, print_every=50, batch_size=128, num_epoch=10):
    """Train a GAN for a certain number of epochs.
    
    Inputs:
    - sess: A tf.Session that we want to use to run our data
    - G_train_step: A training step for the Generator
    - G_loss: Generator loss
    - D_train_step: A training step for the Generator
    - D_loss: Discriminator loss
    - G_extra_step: A collection of tf.GraphKeys.UPDATE_OPS for generator
    - D_extra_step: A collection of tf.GraphKeys.UPDATE_OPS for discriminator
    Returns:
        Nothing
    """
    # compute the number of iterations we need
    max_iter = int(mnist.train.num_examples*num_epoch/batch_size)
    for it in range(max_iter):
        # every show often, show a sample result
        if it % show_every == 0:
            samples = sess.run(G_sample)
            fig = show_images(samples[:16])
            plt.show()
            print()
        # run a batch of data through the network
        minibatch,minbatch_y = mnist.train.next_batch(batch_size)
        _, D_loss_curr = sess.run([D_train_step, D_loss], feed_dict={x: minibatch})
        _, G_loss_curr = sess.run([G_train_step, G_loss], feed_dict={x: minibatch})

        # print loss every so often.
        # We want to make sure D_loss doesn't go to 0
        if it % print_every == 0:
            print('Iter: {}, D: {:.4}, G:{:.4}'.format(it,D_loss_curr,G_loss_curr))
    print('Final images')
    samples = sess.run(G_sample)

    fig = show_images(samples[:16])
    plt.show()

# %% [markdown]
# #### Train your GAN! This should take about 10 minutes on a CPU, or less than a minute on GPU.

# %%
with get_session() as sess:
    sess.run(tf.global_variables_initializer())
    run_a_gan(sess,G_train_step,G_loss,D_train_step,D_loss,G_extra_step,D_extra_step)
# Out:
# Tensor("Shape_18:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_19:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_20:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_21:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_22:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_23:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_24:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_25:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_26:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_27:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_28:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_29:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_30:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_31:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_32:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_33:0", shape=(1,), dtype=int32)
# 28
# Iter: 0, D: 1.675, G:0.7437
# Iter: 50, D: 0.3554, G:1.412
# Iter: 100, D: 1.015, G:1.405
# Iter: 150, D: 1.032, G:1.385
# Iter: 200, D: 0.7556, G:1.648
# Tensor("Shape_34:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_35:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_36:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_37:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_38:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_39:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_40:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_41:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_42:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_43:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_44:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_45:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_46:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_47:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_48:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_49:0", shape=(1,), dtype=int32)
# 28
# Iter: 250, D: 1.74, G:1.211
# Iter: 300, D: 1.505, G:1.049
# Iter: 350, D: 1.041, G:1.375
# Iter: 400, D: 1.174, G:1.855
# Iter: 450, D: 1.181, G:1.033
# Tensor("Shape_50:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_51:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_52:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_53:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_54:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_55:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_56:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_57:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_58:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_59:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_60:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_61:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_62:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_63:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_64:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_65:0", shape=(1,), dtype=int32)
# 28
# Iter: 500, D: 1.069, G:1.206
# Iter: 550, D: 1.171, G:1.187
# Iter: 600, D: 1.526, G:1.233
# Iter: 650, D: 1.102, G:1.279
# Iter: 700, D: 0.929, G:2.282
# Tensor("Shape_66:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_67:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_68:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_69:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_70:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_71:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_72:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_73:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_74:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_75:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_76:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_77:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_78:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_79:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_80:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_81:0", shape=(1,), dtype=int32)
# 28
# Iter: 750, D: 1.129, G:0.9486
# Iter: 800, D: 1.121, G:1.259
# Iter: 850, D: 1.129, G:1.715
# Iter: 900, D: 1.153, G:1.145
# Iter: 950, D: 1.202, G:1.093
# Tensor("Shape_82:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_83:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_84:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_85:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_86:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_87:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_88:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_89:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_90:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_91:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_92:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_93:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_94:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_95:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_96:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_97:0", shape=(1,), dtype=int32)
# 28
# Iter: 1000, D: 1.242, G:1.024
# Iter: 1050, D: 1.19, G:3.023
# Iter: 1100, D: 1.314, G:0.9478
# Iter: 1150, D: 1.165, G:0.9018
# Iter: 1200, D: 1.381, G:1.835
# Tensor("Shape_98:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_99:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_100:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_101:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_102:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_103:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_104:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_105:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_106:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_107:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_108:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_109:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_110:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_111:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_112:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_113:0", shape=(1,), dtype=int32)
# 28
# Iter: 1250, D: 1.304, G:0.9036
# Iter: 1300, D: 1.376, G:1.411
# Iter: 1350, D: 1.289, G:1.064
# Iter: 1400, D: 1.22, G:1.207
# Iter: 1450, D: 1.338, G:0.9216
# Tensor("Shape_114:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_115:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_116:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_117:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_118:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_119:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_120:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_121:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_122:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_123:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_124:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_125:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_126:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_127:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_128:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_129:0", shape=(1,), dtype=int32)
# 28
# Iter: 1500, D: 1.247, G:1.1
# Iter: 1550, D: 1.323, G:0.7277
# Iter: 1600, D: 1.061, G:1.276
# Iter: 1650, D: 1.292, G:0.9796
# Iter: 1700, D: 1.307, G:1.022
# Tensor("Shape_130:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_131:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_132:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_133:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_134:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_135:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_136:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_137:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_138:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_139:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_140:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_141:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_142:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_143:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_144:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_145:0", shape=(1,), dtype=int32)
# 28
# Iter: 1750, D: 1.214, G:1.076
# Iter: 1800, D: 1.283, G:0.8135
# Iter: 1850, D: 1.24, G:2.492
# Iter: 1900, D: 1.283, G:0.9198
# Iter: 1950, D: 1.324, G:0.9097
# Tensor("Shape_146:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_147:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_148:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_149:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_150:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_151:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_152:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_153:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_154:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_155:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_156:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_157:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_158:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_159:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_160:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_161:0", shape=(1,), dtype=int32)
# 28
# Iter: 2000, D: 1.292, G:0.8527
# Iter: 2050, D: 1.316, G:0.5883
# Iter: 2100, D: 1.387, G:1.083
# Iter: 2150, D: 1.264, G:0.8884
# Iter: 2200, D: 1.354, G:0.823
# Tensor("Shape_162:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_163:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_164:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_165:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_166:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_167:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_168:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_169:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_170:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_171:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_172:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_173:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_174:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_175:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_176:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_177:0", shape=(1,), dtype=int32)
# 28
# Iter: 2250, D: 1.326, G:0.9137
# Iter: 2300, D: 1.317, G:0.8201
# Iter: 2350, D: 1.251, G:0.9087
# Iter: 2400, D: 1.357, G:0.8502
# Iter: 2450, D: 1.36, G:0.8046
# Tensor("Shape_178:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_179:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_180:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_181:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_182:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_183:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_184:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_185:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_186:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_187:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_188:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_189:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_190:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_191:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_192:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_193:0", shape=(1,), dtype=int32)
# 28
# Iter: 2500, D: 1.369, G:0.7824
# Iter: 2550, D: 1.362, G:0.738
# Iter: 2600, D: 1.286, G:0.8019
# Iter: 2650, D: 1.364, G:0.9186
# Iter: 2700, D: 1.325, G:0.7715
# Tensor("Shape_194:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_195:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_196:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_197:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_198:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_199:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_200:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_201:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_202:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_203:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_204:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_205:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_206:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_207:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_208:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_209:0", shape=(1,), dtype=int32)
# 28
# Iter: 2750, D: 1.316, G:0.8076
# Iter: 2800, D: 1.295, G:0.8393
# Iter: 2850, D: 1.287, G:0.8365
# Iter: 2900, D: 1.363, G:0.7828
# Iter: 2950, D: 1.358, G:0.9708
# Tensor("Shape_210:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_211:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_212:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_213:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_214:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_215:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_216:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_217:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_218:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_219:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_220:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_221:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_222:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_223:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_224:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_225:0", shape=(1,), dtype=int32)
# 28
# Iter: 3000, D: 1.274, G:0.9741
# Iter: 3050, D: 1.395, G:0.7948
# Iter: 3100, D: 1.353, G:0.8013
# Iter: 3150, D: 1.335, G:0.8769
# Iter: 3200, D: 1.367, G:0.8182
# Tensor("Shape_226:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_227:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_228:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_229:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_230:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_231:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_232:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_233:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_234:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_235:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_236:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_237:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_238:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_239:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_240:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_241:0", shape=(1,), dtype=int32)
# 28
# Iter: 3250, D: 1.265, G:0.8293
# Iter: 3300, D: 1.396, G:0.7943
# Iter: 3350, D: 1.369, G:0.7888
# Iter: 3400, D: 1.309, G:0.8164
# Iter: 3450, D: 1.371, G:0.8212
# Tensor("Shape_242:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_243:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_244:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_245:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_246:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_247:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_248:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_249:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_250:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_251:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_252:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_253:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_254:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_255:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_256:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_257:0", shape=(1,), dtype=int32)
# 28
# Iter: 3500, D: 1.333, G:0.8
# Iter: 3550, D: 1.351, G:0.8207
# Iter: 3600, D: 1.287, G:0.8355
# Iter: 3650, D: 1.284, G:0.7473
# Iter: 3700, D: 1.359, G:0.7593
# Tensor("Shape_258:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_259:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_260:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_261:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_262:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_263:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_264:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_265:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_266:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_267:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_268:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_269:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_270:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_271:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_272:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_273:0", shape=(1,), dtype=int32)
# 28
# Iter: 3750, D: 1.321, G:0.7529
# Iter: 3800, D: 1.301, G:0.8401
# Iter: 3850, D: 1.353, G:0.8268
# Iter: 3900, D: 1.266, G:0.9059
# Iter: 3950, D: 1.276, G:0.7524
# Tensor("Shape_274:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_275:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_276:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_277:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_278:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_279:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_280:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_281:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_282:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_283:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_284:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_285:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_286:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_287:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_288:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_289:0", shape=(1,), dtype=int32)
# 28
# Iter: 4000, D: 1.368, G:0.7934
# Iter: 4050, D: 1.281, G:0.815
# Iter: 4100, D: 1.281, G:0.7906
# Iter: 4150, D: 1.352, G:0.9489
# Iter: 4200, D: 1.346, G:0.7726
# Tensor("Shape_290:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_291:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_292:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_293:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_294:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_295:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_296:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_297:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_298:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_299:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_300:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_301:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_302:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_303:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_304:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_305:0", shape=(1,), dtype=int32)
# 28
# Iter: 4250, D: 1.362, G:0.7697
# Final images
# Tensor("Shape_306:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_307:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_308:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_309:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_310:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_311:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_312:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_313:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_314:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_315:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_316:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_317:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_318:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_319:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_320:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_321:0", shape=(1,), dtype=int32)
# 28

# %% [markdown]
# # Least Squares GAN
# We'll now look at [Least Squares GAN](https://arxiv.org/abs/1611.04076), a newer, more stable alternative to the original GAN loss function. For this part, all we have to do is change the loss function and retrain the model. We'll implement equation (9) in the paper, with the generator loss:
# $$\ell_G  =  \frac{1}{2}\mathbb{E}_{z \sim p(z)}\left[\left(D(G(z))-1\right)^2\right]$$
# and the discriminator loss:
# $$ \ell_D = \frac{1}{2}\mathbb{E}_{x \sim p_\text{data}}\left[\left(D(x)-1\right)^2\right] + \frac{1}{2}\mathbb{E}_{z \sim p(z)}\left[ \left(D(G(z))\right)^2\right]$$
#
#
# **HINTS**: Instead of computing the expectation, we will be averaging over elements of the minibatch, so make sure to combine the loss by averaging instead of summing. When plugging in for $D(x)$ and $D(G(z))$ use the direct output from the discriminator (`score_real` and `score_fake`).

# %%
def lsgan_loss(score_real, score_fake):
    """Compute the Least Squares GAN loss.
    
    Inputs:
    - score_real: Tensor, shape [batch_size, 1], output of discriminator
        score for each real image
    - score_fake: Tensor, shape[batch_size, 1], output of discriminator
        score for each fake image    
          
    Returns:
    - D_loss: discriminator loss scalar
    - G_loss: generator loss scalar
    """
    # TODO: compute D_loss and G_loss
    D_loss = None
    G_loss = None
    pass  
    G_loss = 0.5 * tf.reduce_mean((score_fake - 1) ** 2)
    D_loss = 0.5 * tf.reduce_mean((score_real - 1) ** 2) + 0.5 * tf.reduce_mean(score_fake ** 2)

    return D_loss, G_loss

# %% [markdown]
# Test your LSGAN loss. You should see errors less than 1e-7.

# %%
def test_lsgan_loss(score_real, score_fake, d_loss_true, g_loss_true):
    with get_session() as sess:
        d_loss, g_loss = sess.run(
            lsgan_loss(tf.constant(score_real), tf.constant(score_fake)))
    print("Maximum error in d_loss: %g"%rel_error(d_loss_true, d_loss))
    print("Maximum error in g_loss: %g"%rel_error(g_loss_true, g_loss))

test_lsgan_loss(answers['logits_real'], answers['logits_fake'],
                answers['d_loss_lsgan_true'], answers['g_loss_lsgan_true'])
# Out:
# Maximum error in d_loss: 0
# Maximum error in g_loss: 0

# %% [markdown]
# Create new training steps so we instead minimize the LSGAN loss:

# %%
D_loss, G_loss = lsgan_loss(logits_real, logits_fake)
D_train_step = D_solver.minimize(D_loss, var_list=D_vars)
G_train_step = G_solver.minimize(G_loss, var_list=G_vars)

# %%
with get_session() as sess:
    sess.run(tf.global_variables_initializer())
    run_a_gan(sess, G_train_step, G_loss, D_train_step, D_loss, G_extra_step, D_extra_step)
# Out:
# Tensor("Shape_322:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_323:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_324:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_325:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_326:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_327:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_328:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_329:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_330:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_331:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_332:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_333:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_334:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_335:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_336:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_337:0", shape=(1,), dtype=int32)
# 28
# Iter: 0, D: 2.799, G:0.4787
# Iter: 50, D: 0.03043, G:0.9037
# Iter: 100, D: 0.05126, G:0.5996
# Iter: 150, D: 0.06776, G:0.3345
# Iter: 200, D: 0.2844, G:1.386
# Tensor("Shape_338:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_339:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_340:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_341:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_342:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_343:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_344:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_345:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_346:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_347:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_348:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_349:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_350:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_351:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_352:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_353:0", shape=(1,), dtype=int32)
# 28
# Iter: 250, D: 0.2071, G:0.3487
# Iter: 300, D: 0.05967, G:0.4529
# Iter: 350, D: 0.2171, G:1.168
# Iter: 400, D: 0.1018, G:0.5354
# Iter: 450, D: 0.1543, G:0.3751
# Tensor("Shape_354:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_355:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_356:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_357:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_358:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_359:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_360:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_361:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_362:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_363:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_364:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_365:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_366:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_367:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_368:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_369:0", shape=(1,), dtype=int32)
# 28
# Iter: 500, D: 0.08358, G:0.6507
# Iter: 550, D: 0.1141, G:0.464
# Iter: 600, D: 0.09505, G:0.3793
# Iter: 650, D: 0.4961, G:0.5583
# Iter: 700, D: 0.1164, G:0.4267
# Tensor("Shape_370:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_371:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_372:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_373:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_374:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_375:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_376:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_377:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_378:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_379:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_380:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_381:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_382:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_383:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_384:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_385:0", shape=(1,), dtype=int32)
# 28
# Iter: 750, D: 0.1321, G:0.3036
# Iter: 800, D: 0.1145, G:0.5787
# Iter: 850, D: 0.1271, G:0.3682
# Iter: 900, D: 0.1527, G:0.2876
# Iter: 950, D: 0.1512, G:0.3486
# Tensor("Shape_386:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_387:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_388:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_389:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_390:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_391:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_392:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_393:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_394:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_395:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_396:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_397:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_398:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_399:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_400:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_401:0", shape=(1,), dtype=int32)
# 28
# Iter: 1000, D: 0.1676, G:0.05916
# Iter: 1050, D: 0.1578, G:0.2825
# Iter: 1100, D: 0.1282, G:0.347
# Iter: 1150, D: 0.1425, G:0.318
# Iter: 1200, D: 0.141, G:0.2788
# Tensor("Shape_402:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_403:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_404:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_405:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_406:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_407:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_408:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_409:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_410:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_411:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_412:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_413:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_414:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_415:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_416:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_417:0", shape=(1,), dtype=int32)
# 28
# Iter: 1250, D: 0.1165, G:0.3504
# Iter: 1300, D: 0.1389, G:0.314
# Iter: 1350, D: 0.1479, G:0.3292
# Iter: 1400, D: 0.2089, G:0.2217
# Iter: 1450, D: 0.1916, G:0.2233
# Tensor("Shape_418:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_419:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_420:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_421:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_422:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_423:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_424:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_425:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_426:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_427:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_428:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_429:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_430:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_431:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_432:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_433:0", shape=(1,), dtype=int32)
# 28
# Iter: 1500, D: 0.1736, G:0.2278
# Iter: 1550, D: 0.1714, G:0.2824
# Iter: 1600, D: 0.1766, G:0.236
# Iter: 1650, D: 0.1416, G:0.2468
# Iter: 1700, D: 0.1526, G:0.2252
# Tensor("Shape_434:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_435:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_436:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_437:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_438:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_439:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_440:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_441:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_442:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_443:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_444:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_445:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_446:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_447:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_448:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_449:0", shape=(1,), dtype=int32)
# 28
# Iter: 1750, D: 0.1464, G:0.2668
# Iter: 1800, D: 0.2204, G:0.1906
# Iter: 1850, D: 0.2077, G:0.1679
# Iter: 1900, D: 0.1944, G:0.5157
# Iter: 1950, D: 0.2058, G:0.225
# Tensor("Shape_450:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_451:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_452:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_453:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_454:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_455:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_456:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_457:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_458:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_459:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_460:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_461:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_462:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_463:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_464:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_465:0", shape=(1,), dtype=int32)
# 28
# Iter: 2000, D: 0.2212, G:0.1937
# Iter: 2050, D: 0.2035, G:0.2105
# Iter: 2100, D: 0.1899, G:0.2103
# Iter: 2150, D: 0.1847, G:0.1929
# Iter: 2200, D: 0.2074, G:0.1942
# Tensor("Shape_466:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_467:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_468:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_469:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_470:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_471:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_472:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_473:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_474:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_475:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_476:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_477:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_478:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_479:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_480:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_481:0", shape=(1,), dtype=int32)
# 28
# Iter: 2250, D: 0.2139, G:0.1886
# Iter: 2300, D: 0.2195, G:0.2157
# Iter: 2350, D: 0.195, G:0.1344
# Iter: 2400, D: 0.2019, G:0.1842
# Iter: 2450, D: 0.21, G:0.2292
# Tensor("Shape_482:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_483:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_484:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_485:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_486:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_487:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_488:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_489:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_490:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_491:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_492:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_493:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_494:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_495:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_496:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_497:0", shape=(1,), dtype=int32)
# 28
# Iter: 2500, D: 0.2266, G:0.2213
# Iter: 2550, D: 0.2283, G:0.1963
# Iter: 2600, D: 0.2373, G:0.1776
# Iter: 2650, D: 0.2244, G:0.1877
# Iter: 2700, D: 0.2248, G:0.1815
# Tensor("Shape_498:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_499:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_500:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_501:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_502:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_503:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_504:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_505:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_506:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_507:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_508:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_509:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_510:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_511:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_512:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_513:0", shape=(1,), dtype=int32)
# 28
# Iter: 2750, D: 0.2132, G:0.1619
# Iter: 2800, D: 0.2372, G:0.1769
# Iter: 2850, D: 0.2537, G:0.1501
# Iter: 2900, D: 0.2356, G:0.1842
# Iter: 2950, D: 0.2108, G:0.1756
# Tensor("Shape_514:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_515:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_516:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_517:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_518:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_519:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_520:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_521:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_522:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_523:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_524:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_525:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_526:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_527:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_528:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_529:0", shape=(1,), dtype=int32)
# 28
# Iter: 3000, D: 0.2189, G:0.1513
# Iter: 3050, D: 0.2316, G:0.178
# Iter: 3100, D: 0.2176, G:0.1834
# Iter: 3150, D: 0.224, G:0.1761
# Iter: 3200, D: 0.2513, G:0.1886
# Tensor("Shape_530:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_531:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_532:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_533:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_534:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_535:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_536:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_537:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_538:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_539:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_540:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_541:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_542:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_543:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_544:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_545:0", shape=(1,), dtype=int32)
# 28
# Iter: 3250, D: 0.2166, G:0.1706
# Iter: 3300, D: 0.2251, G:0.1979
# Iter: 3350, D: 0.2265, G:0.1783
# Iter: 3400, D: 0.2342, G:0.1755
# Iter: 3450, D: 0.2216, G:0.1745
# Tensor("Shape_546:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_547:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_548:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_549:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_550:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_551:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_552:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_553:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_554:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_555:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_556:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_557:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_558:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_559:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_560:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_561:0", shape=(1,), dtype=int32)
# 28
# Iter: 3500, D: 0.2276, G:0.1608
# Iter: 3550, D: 0.2228, G:0.1784
# Iter: 3600, D: 0.2302, G:0.1632
# Iter: 3650, D: 0.2255, G:0.173
# Iter: 3700, D: 0.2401, G:0.172
# Tensor("Shape_562:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_563:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_564:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_565:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_566:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_567:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_568:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_569:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_570:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_571:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_572:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_573:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_574:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_575:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_576:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_577:0", shape=(1,), dtype=int32)
# 28
# Iter: 3750, D: 0.2399, G:0.1569
# Iter: 3800, D: 0.2241, G:0.1742
# Iter: 3850, D: 0.2318, G:0.1743
# Iter: 3900, D: 0.2125, G:0.1822
# Iter: 3950, D: 0.2287, G:0.187
# Tensor("Shape_578:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_579:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_580:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_581:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_582:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_583:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_584:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_585:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_586:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_587:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_588:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_589:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_590:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_591:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_592:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_593:0", shape=(1,), dtype=int32)
# 28
# Iter: 4000, D: 0.2515, G:0.1652
# Iter: 4050, D: 0.2181, G:0.1676
# Iter: 4100, D: 0.223, G:0.1835
# Iter: 4150, D: 0.2333, G:0.1676
# Iter: 4200, D: 0.2379, G:0.1739
# Tensor("Shape_594:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_595:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_596:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_597:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_598:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_599:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_600:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_601:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_602:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_603:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_604:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_605:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_606:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_607:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_608:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_609:0", shape=(1,), dtype=int32)
# 28
# Iter: 4250, D: 0.2331, G:0.1866
# Final images
# Tensor("Shape_610:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_611:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_612:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_613:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_614:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_615:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_616:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_617:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_618:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_619:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_620:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_621:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_622:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_623:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_624:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_625:0", shape=(1,), dtype=int32)
# 28

# %% [markdown]
# # INLINE QUESTION 1:
# Describe how the visual quality of the samples changes over the course of training. Do you notice anything about the distribution of the samples? How do the results change across different training runs?

# %% [markdown]
# ** (Write Your Answer In This Cell) **

# %% [markdown]
# # Deep Convolutional GANs
# In the first part of the notebook, we implemented an almost direct copy of the original GAN network from Ian Goodfellow. However, this network architecture allows no real spatial reasoning. It is unable to reason about things like "sharp edges" in general because it lacks any convolutional layers. Thus, in this section, we will implement some of the ideas from [DCGAN](https://arxiv.org/abs/1511.06434), where we use convolutional networks as our discriminators and generators.
#
# #### Discriminator
# We will use a discriminator inspired by the TensorFlow MNIST classification [tutorial](https://www.tensorflow.org/get_started/mnist/pros), which is able to get above 99% accuracy on the MNIST dataset fairly quickly. *Be sure to check the dimensions of x and reshape when needed*, fully connected blocks expect [N,D] Tensors while conv2d blocks expect [N,H,W,C] Tensors.
#
# Architecture:
# * 32 Filters, 5x5, Stride 1, Leaky ReLU(alpha=0.01)
# * Max Pool 2x2, Stride 2
# * 64 Filters, 5x5, Stride 1, Leaky ReLU(alpha=0.01)
# * Max Pool 2x2, Stride 2
# * Flatten
# * Fully Connected size 4 x 4 x 64, Leaky ReLU(alpha=0.01)
# * Fully Connected size 1

# %%
def discriminator(x):
    """Compute discriminator score for a batch of input images.
    
    Inputs:
    - x: TensorFlow Tensor of flattened input images, shape [batch_size, 784]
    
    Returns:
    TensorFlow Tensor with shape [batch_size, 1], containing the score 
    for an image being real for each input image.
    """
    with tf.variable_scope("discriminator"):
        pass
        input = tf.reshape(x,[-1,28,28,1])
        conv1 = tf.layers.conv2d(inputs = input, filters = 32,kernel_size = 5,strides = 1,padding='valid',activation=None,use_bias=True)
        h1 = leaky_relu(conv1)
        max_pool1 = tf.layers.max_pooling2d(inputs = h1,pool_size = (2,2), strides = (2,2), padding = 'valid')
        conv2 = tf.layers.conv2d(inputs = max_pool1, filters = 64,kernel_size = (5,5),strides = (1,1),padding='valid',
    activation=None,use_bias=True)
        h2 = leaky_relu(conv2)
        max_pool2 = tf.layers.max_pooling2d(inputs = h2,pool_size = (2,2), strides = (2,2), padding = 'valid')
        s = tf.shape(max_pool2)
        print(s[0],s[1],s[2],s[3])
        h3 = tf.reshape(max_pool2,[-1,1024])
        f1 = tf.layers.dense(inputs = h3,units = 4 * 4 * 64,use_bias = True,activation = None)
        h4 = leaky_relu(f1)
        logits = tf.layers.dense(inputs = h4,units = 1,use_bias = True,activation = None)
        return logits
test_discriminator(1102721)
# Out:
# Tensor("discriminator/strided_slice:0", shape=(), dtype=int32) Tensor("discriminator/strided_slice_1:0", shape=(), dtype=int32) Tensor("discriminator/strided_slice_2:0", shape=(), dtype=int32) Tensor("discriminator/strided_slice_3:0", shape=(), dtype=int32)
# Correct number of parameters in discriminator.

# %% [markdown]
# #### Generator
# For the generator, we will copy the architecture exactly from the [InfoGAN paper](https://arxiv.org/pdf/1606.03657.pdf). See Appendix C.1 MNIST. See the documentation for [tf.nn.conv2d_transpose](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d_transpose). We are always "training" in GAN mode.
#
# Architecture:
# * Fully connected of size 1024, ReLU
# * BatchNorm
# * Fully connected of size 7 x 7 x 128, ReLU
# * BatchNorm
# * Resize into Image Tensor
# * 64 conv2d^T (transpose) filters of 4x4, stride 2, ReLU
# * BatchNorm
# * 1 conv2d^T (transpose) filter of 4x4, stride 2, TanH

# %%
def generator(z):
    """Generate images from a random noise vector.
    
    Inputs:
    - z: TensorFlow Tensor of random noise with shape [batch_size, noise_dim]
    
    Returns:
    TensorFlow Tensor of generated images, with shape [batch_size, 784].
    """
    with tf.variable_scope("generator"):
        # TODO: implement architecture
        pass
        f1 = tf.layers.dense(inputs = z, units = 1024, use_bias = True, activation = tf.nn.relu)
        b1 = tf.layers.batch_normalization(inputs = f1,axis = -1)
        f2 = tf.layers.dense(inputs = b1, units = 7 * 7 * 128, use_bias = True, activation = tf.nn.relu)
        b2 = tf.layers.batch_normalization(inputs = f2,axis = -1)
        img = tf.reshape(b2,[-1,7,7,128])
        conv1 = tf.layers.conv2d_transpose(inputs = img,filters = 64, kernel_size = 4,strides = 2,
                                   padding = 'same',activation = tf.nn.relu, use_bias = True)
        b3 = tf.layers.batch_normalization(inputs = conv1,axis = -1)
        conv2 = tf.layers.conv2d_transpose(inputs = b3,filters = 1, kernel_size = 4, strides = 2,
                                   padding = 'same',activation = tf.nn.tanh, use_bias = True)
        return conv2
test_generator(6595521)
# Out:
# Correct number of parameters in generator.
# '\n    with tf.variable_scope("generator"):\n        # TODO: implement architecture\n        pass\n        f1 = tf.layers.dense(inputs = z, units = 1024, use_bias = True, activation = tf.nn.relu)\n        b1 = tf.layers.batch_normalization(inputs = f1,axis = -1)\n        f2 = tf.layers.dense(inputs = b1, units = 7 * 7 * 128, use_bias = True, activation = tf.nn.relu)\n        b2 = tf.layers.batch_normalization(inputs = f2,axis = -1)\n        img = tf.reshape(b2,[-1,7,7,128])\n        conv1 = tf.layers.conv2d_transpose(inputs = img,filters = 64, kernel_size = 4,strides = 2,\n                                   padding = \'same\',activation = tf.nn.relu, use_bias = True)\n        b3 = tf.layers.batch_normalization(inputs = conv1,axis = -1)\n        conv2 = tf.layers.conv2d_transpose(inputs = b3,filters = 1, kernel_size = 4, strides = 2,\n                                   padding = \'same\',activation = tf.nn.tanh, use_bias = True)\n        return img\ntest_generator(6595521)\n'

# %% [markdown]
# We have to recreate our network since we've changed our functions.

# %%
tf.reset_default_graph()

batch_size = 128
# our noise dimension
noise_dim = 96

# placeholders for images from the training dataset
x = tf.placeholder(tf.float32, [None, 784])
z = sample_noise(batch_size, noise_dim)
# generated images
G_sample = generator(z)

with tf.variable_scope("") as scope:
    #scale images to be -1 to 1
    logits_real = discriminator(preprocess_img(x))
    # Re-use discriminator weights on new inputs
    scope.reuse_variables()
    logits_fake = discriminator(G_sample)

# Get the list of variables for the discriminator and generator
D_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,'discriminator')
G_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,'generator') 

D_solver,G_solver = get_solvers()
D_loss, G_loss = gan_loss(logits_real, logits_fake)
D_train_step = D_solver.minimize(D_loss, var_list=D_vars)
G_train_step = G_solver.minimize(G_loss, var_list=G_vars)
D_extra_step = tf.get_collection(tf.GraphKeys.UPDATE_OPS,'discriminator')
G_extra_step = tf.get_collection(tf.GraphKeys.UPDATE_OPS,'generator')
# Out:
# Tensor("discriminator/strided_slice:0", shape=(), dtype=int32) Tensor("discriminator/strided_slice_1:0", shape=(), dtype=int32) Tensor("discriminator/strided_slice_2:0", shape=(), dtype=int32) Tensor("discriminator/strided_slice_3:0", shape=(), dtype=int32)
# Tensor("discriminator_1/strided_slice:0", shape=(), dtype=int32) Tensor("discriminator_1/strided_slice_1:0", shape=(), dtype=int32) Tensor("discriminator_1/strided_slice_2:0", shape=(), dtype=int32) Tensor("discriminator_1/strided_slice_3:0", shape=(), dtype=int32)
# Tensor("ones_like:0", shape=(?, 1), dtype=float32) Tensor("zeros_like:0", shape=(128, 1), dtype=float32)

# %% [markdown]
# ### Train and evaluate a DCGAN
# This is the one part of A3 that significantly benefits from using a GPU. It takes 3 minutes on a GPU for the requested five epochs. Or about 50 minutes on a dual core laptop on CPU (feel free to use 3 epochs if you do it on CPU).

# %%
def run_a_gan(sess, G_train_step, G_loss, D_train_step, D_loss, G_extra_step, D_extra_step,\
              show_every=250, print_every=50, batch_size=128, num_epoch=10):
    """Train a GAN for a certain number of epochs.
    
    Inputs:
    - sess: A tf.Session that we want to use to run our data
    - G_train_step: A training step for the Generator
    - G_loss: Generator loss
    - D_train_step: A training step for the Generator
    - D_loss: Discriminator loss
    - G_extra_step: A collection of tf.GraphKeys.UPDATE_OPS for generator
    - D_extra_step: A collection of tf.GraphKeys.UPDATE_OPS for discriminator
    Returns:
        Nothing
    """
    # compute the number of iterations we need
    max_iter = int(mnist.train.num_examples*num_epoch/batch_size)
    for it in range(max_iter):
        # every show often, show a sample result
        if it % show_every == 0:
            samples = sess.run(G_sample)
            fig = show_images(samples[:16])
            plt.show()
            print()
        # run a batch of data through the network
        minibatch,minbatch_y = mnist.train.next_batch(batch_size)
        if it % 3 == 0:
            _, D_loss_curr = sess.run([D_train_step, D_loss], feed_dict={x: minibatch})
        _, G_loss_curr = sess.run([G_train_step, G_loss], feed_dict={x: minibatch})

        # print loss every so often.
        # We want to make sure D_loss doesn't go to 0
        if it % print_every == 0:
            print('Iter: {}, D: {:.4}, G:{:.4}'.format(it,D_loss_curr,G_loss_curr))
    print('Final images')
    samples = sess.run(G_sample)

    fig = show_images(samples[:16])
    plt.show()
with get_session() as sess:
    sess.run(tf.global_variables_initializer())
    run_a_gan(sess,G_train_step,G_loss,D_train_step,D_loss,G_extra_step,D_extra_step,num_epoch=5)
# Out:
# Tensor("Shape_2:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_3:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_4:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_5:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_6:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_7:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_8:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_9:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_10:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_11:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_12:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_13:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_14:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_15:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_16:0", shape=(1,), dtype=int32)
# 28
# Tensor("Shape_17:0", shape=(1,), dtype=int32)
# 28
# Iter: 0, D: 1.352, G:0.6543
# Iter: 50, D: 1.409, G:0.8736

# %% [markdown]
# # INLINE QUESTION 2:
# What differences do you see between the DCGAN results and the original GAN results?

# %% [markdown]
# ** (Write Your Answer In This Cell) **

# %% [markdown]
# ------
#
# # Extra Credit
# ** Be sure you don't destroy your results above, but feel free to copy+paste code to get results below **
# * For a small amount of extra credit, you can implement additional new GAN loss functions below, provided they converge. See AFI, BiGAN, Softmax GAN, Conditional GAN, InfoGAN, etc. They should converge to get credit.
# * Likewise for an improved architecture or using a convolutional GAN (or even implement a VAE)
# * For a bigger chunk of extra credit, load the CIFAR10 data (see last assignment) and train a compelling generative model on CIFAR-10
# * Demonstrate the value of GANs in building semi-supervised models. In a semi-supervised example, only some fraction of the input data has labels; we can supervise this in MNIST by only training on a few dozen or hundred labeled examples. This was first described in [Improved Techniques for Training GANs](https://arxiv.org/abs/1606.03498).
# * Something new/cool.
#
# #### Describe what you did here

# %% [markdown]
# # WGAN-GP (Small Extra Credit)
#
# Please only attempt after you have completed everything above.
#
# We'll now look at [Improved Wasserstein GAN](https://arxiv.org/abs/1704.00028) as a newer, more stable alernative to the original GAN loss function. For this part, all we have to do is change the loss function and retrain the model. We'll implement Algorithm 1 in the paper.
#
# You'll also need to use a discriminator and corresponding generator without max-pooling. So we cannot use the one we currently have from DCGAN. Pair the DCGAN Generator (from InfoGAN) with the discriminator from [InfoGAN](https://arxiv.org/pdf/1606.03657.pdf) Appendix C.1 MNIST (We don't use Q, simply implement the network up to D). You're also welcome to define a new generator and discriminator in this notebook, in case you want to use the fully-connected pair of D(x) and G(z) you used at the top of this notebook.
#
# Architecture:
# * 64 Filters of 4x4, stride 2, LeakyReLU
# * 128 Filters of 4x4, stride 2, LeakyReLU
# * BatchNorm
# * Flatten
# * Fully connected 1024, LeakyReLU
# * Fully connected size 1

# %%
def discriminator(x):
    with tf.variable_scope('discriminator'):
        # TODO: implement architecture
        pass
        return logits
test_discriminator(3411649)

# %%
tf.reset_default_graph()

batch_size = 128
# our noise dimension
noise_dim = 96

# placeholders for images from the training dataset
x = tf.placeholder(tf.float32, [None, 784])
z = sample_noise(batch_size, noise_dim)
# generated images
G_sample = generator(z)

with tf.variable_scope("") as scope:
    #scale images to be -1 to 1
    logits_real = discriminator(preprocess_img(x))
    # Re-use discriminator weights on new inputs
    scope.reuse_variables()
    logits_fake = discriminator(G_sample)

# Get the list of variables for the discriminator and generator
D_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,'discriminator')
G_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,'generator')

D_solver, G_solver = get_solvers()

# %%
def wgangp_loss(logits_real, logits_fake, batch_size, x, G_sample):
    """Compute the WGAN-GP loss.
    
    Inputs:
    - logits_real: Tensor, shape [batch_size, 1], output of discriminator
        Log probability that the image is real for each real image
    - logits_fake: Tensor, shape[batch_size, 1], output of discriminator
        Log probability that the image is real for each fake image
    - batch_size: The number of examples in this batch
    - x: the input (real) images for this batch
    - G_sample: the generated (fake) images for this batch
    
    Returns:
    - D_loss: discriminator loss scalar
    - G_loss: generator loss scalar
    """
    # TODO: compute D_loss and G_loss
    D_loss = None
    G_loss = None

    # lambda from the paper
    lam = 10
    
    # random sample of batch_size (tf.random_uniform)
    eps = 0
    x_hat = 0

    # Gradients of Gradients is kind of tricky!
    with tf.variable_scope('',reuse=True) as scope:
        grad_D_x_hat = None

    grad_norm = None
    grad_pen = None



    return D_loss, G_loss

D_loss, G_loss = wgangp_loss(logits_real, logits_fake, 128, x, G_sample)
D_train_step = D_solver.minimize(D_loss, var_list=D_vars)
G_train_step = G_solver.minimize(G_loss, var_list=G_vars)
D_extra_step = tf.get_collection(tf.GraphKeys.UPDATE_OPS,'discriminator')
G_extra_step = tf.get_collection(tf.GraphKeys.UPDATE_OPS,'generator')

# %%
with get_session() as sess:
    sess.run(tf.global_variables_initializer())
    run_a_gan(sess,G_train_step,G_loss,D_train_step,D_loss,G_extra_step,D_extra_step,batch_size=128,num_epoch=5)
